# %%
from mmseg.apis import inference
# Out:
# /home/zhy/miniconda3/envs/mmlab/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
PALETTE = [(0,0,0), (0,0,255), (0,255,0), (0,255,255), (255,0,0), (255,0,255), (255,255,0), (255,255,255)]
PALETTE = [item[::-1] for item in PALETTE]

img_path = "./d_r_403_.jpg"
model = inference.init_segmentor("config.py", "work_dir/best_aAcc_epoch_80.pth")
result = inference.inference_segmentor(model, img_path)
inference.show_result_pyplot(model, img_path, result, PALETTE, opacity=.4, out_file="output.png")

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
PALETTE = [(0,0,0), (0,0,255), (0,255,0), (0,255,255), (255,0,0), (255,0,255), (255,255,0), (255,255,255)]
mask = cv.imread("data/pre_mask/d_r_174_.png")
img = np.zeros_like(mask)

# %%
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        img[i, j] = PALETTE[mask[i, j, 0]]

# %%
plt.imshow(img[..., ::-1])
